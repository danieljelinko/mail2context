# %%
#| default_exp core

# %% [markdown]
# # core
#
# > Core functionality for mail2context

# %%
#| export
from fastcore.basics import *

# %%
#| hide
from mail2context.utils.my_test import *

# %%
#| export
def hello():
    "Say hello"
    return "Hello from mail2context!"

# %%
test_eq(hello(), "Hello from mail2context!")

# %%
#| hide
import nbdev; nbdev.nbdev_export()
